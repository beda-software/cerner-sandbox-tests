# %%
from fhirpy import SyncFHIRClient
from fhirpy.base.searchset import Raw
from fhirpathpy import evaluate as fhirpath
import json
import funcy

def pp(obj):
    print(json.dumps(obj, indent=2, separators=(',', ': ')))

# %%
BASE_URL = "https://fhir-open.cerner.com/r4/ec2458f2-1e24-41c8-b71b-0e701af7583d/"

# %%
print(BASE_URL)
# Out:
# https://fhir-open.cerner.com/r4/ec2458f2-1e24-41c8-b71b-0e701af7583d/

# %%
client = SyncFHIRClient(
    BASE_URL,
)
client
# Out:
# <SyncFHIRClient https://fhir-open.cerner.com/r4/ec2458f2-1e24-41c8-b71b-0e701af7583d/>

# %%
client.resources("Procedure").search(patient="12724066").fetch()
# Out:
# [<SyncFHIRResource Procedure/2574524413>,
#  <SyncFHIRResource Procedure/2574634201>,
#  <SyncFHIRResource Procedure/2574524477>,
#  <SyncFHIRResource Procedure/2574524895>,
#  <SyncFHIRResource Procedure/2574524549>,
#  <SyncFHIRResource Procedure/2574633995>,
#  <SyncFHIRResource Procedure/2574622307>,
#  <SyncFHIRResource Procedure/2574524919>,
#  <SyncFHIRResource Procedure/2574635581>,
#  <SyncFHIRResource Procedure/2574634465>,
#  <SyncFHIRResource Procedure/2574634457>,
#  <SyncFHIRResource Procedure/2574634003>,
#  <SyncFHIRResource Procedure/2574524887>,
#  <SyncFHIRResource Procedure/2574524879>,
#  <SyncFHIRResource Procedure/2574524635>,
#  <SyncFHIRResource Procedure/2574524627>,
#  <SyncFHIRResource Procedure/2574524619>,
#  <SyncFHIRResource Procedure/2574524611>,
#  <SyncFHIRResource Procedure/2574524603>,
#  <SyncFHIRResource Procedure/2574524595>,
#  <SyncFHIRResource Procedure/2574524587>,
#  <SyncFHIRResource Procedure/2574524579>,
#  <SyncFHIRResource Procedure/2574524571>,
#  <SyncFHIRResource Procedure/2574524565>,
#  <SyncFHIRResource Procedure/2574524557>,
#  <SyncFHIRResource Procedure/2574524525>,
#  <SyncFHIRResource Procedure/2574524517>,
#  <SyncFHIRResource Procedure/2574524509>,
#  <SyncFHIRResource Procedure/2574524501>,
#  <SyncFHIRResource Procedure/2574524493>,
#  <SyncFHIRResource Procedure/2574524485>,
#  <SyncFHIRResource Procedure/2574524469>,
#  <SyncFHIRResource Procedure/2574524461>,
#  <SyncFHIRResource Procedure/2574524453>,
#  <SyncFHIRResource Procedure/2574524445>,
#  <SyncFHIRResource Procedure/2574524437>,
#  <SyncFHIRResource Procedure/2574524429>,
#  <SyncFHIRResource Procedure/2574524421>,
#  <SyncFHIRResource Procedure/2574816813>,
#  <SyncFHIRResource Procedure/2574815733>,
#  <SyncFHIRResource Procedure/2574815747>,
#  <SyncFHIRResource Procedure/2574815727>,
#  <SyncFHIRResource Procedure/2574646993>,
#  <SyncFHIRResource Procedure/2574876933>,
#  <SyncFHIRResource Procedure/2574842067>,
#  <SyncFHIRResource Procedure/2574637367>,
#  <SyncFHIRResource Procedure/2574637233>,
#  <SyncFHIRResource Procedure/2574636959>,
#  <SyncFHIRResource Procedure/2574533055>,
#  <SyncFHIRResource Procedure/2574524911>,
#  <SyncFHIRResource Procedure/2573063297>,
#  <SyncFHIRResource Procedure/2572765397>,
#  <SyncFHIRResource Procedure/2572765389>,
#  <SyncFHIRResource Procedure/2574647973>,
#  <SyncFHIRResource Procedure/2574520479>,
#  <SyncFHIRResource Procedure/2574536729>,
#  <SyncFHIRResource Procedure/2574520473>,
#  <SyncFHIRResource Procedure/2574524833>,
#  <SyncFHIRResource Procedure/2574524823>,
#  <SyncFHIRResource Procedure/2574524405>,
#  <SyncFHIRResource Procedure/2574524091>,
#  <SyncFHIRResource Procedure/2574524083>,
#  <SyncFHIRResource Procedure/2574524075>,
#  <SyncFHIRResource Procedure/2574524067>,
#  <SyncFHIRResource Procedure/2574524059>,
#  <SyncFHIRResource Procedure/2574524051>,
#  <SyncFHIRResource Procedure/2574524043>,
#  <SyncFHIRResource Procedure/2574524035>,
#  <SyncFHIRResource Procedure/2574524027>,
#  <SyncFHIRResource Procedure/2574524019>,
#  <SyncFHIRResource Procedure/2574524011>,
#  <SyncFHIRResource Procedure/2574524003>,
#  <SyncFHIRResource Procedure/2574523995>,
#  <SyncFHIRResource Procedure/2574523987>,
#  <SyncFHIRResource Procedure/2574523979>,
#  <SyncFHIRResource Procedure/2574523971>,
#  <SyncFHIRResource Procedure/2574523963>,
#  <SyncFHIRResource Procedure/2574523955>,
#  <SyncFHIRResource Procedure/2574523947>,
#  <SyncFHIRResource Procedure/2574523939>,
#  <SyncFHIRResource Procedure/2574523899>,
#  <SyncFHIRResource Procedure/2574523891>,
#  <SyncFHIRResource Procedure/2574523883>,
#  <SyncFHIRResource Procedure/2574523875>,
#  <SyncFHIRResource Procedure/2574523867>,
#  <SyncFHIRResource Procedure/2574523859>,
#  <SyncFHIRResource Procedure/2574523677>,
#  <SyncFHIRResource Procedure/2574523667>,
#  <SyncFHIRResource Procedure/2574522903>,
#  <SyncFHIRResource Procedure/2574522897>,
#  <SyncFHIRResource Procedure/2574522833>,
#  <SyncFHIRResource Procedure/2574520971>,
#  <SyncFHIRResource Procedure/2574520949>,
#  <SyncFHIRResource Procedure/2574520939>,
#  <SyncFHIRResource Procedure/2574520641>,
#  <SyncFHIRResource Procedure/2574520627>,
#  <SyncFHIRResource Procedure/2574520617>,
#  <SyncFHIRResource Procedure/2574520607>,
#  <SyncFHIRResource Procedure/2574520597>,
#  <SyncFHIRResource Procedure/2574520577>,
#  <SyncFHIRResource Procedure/2574520567>,
#  <SyncFHIRResource Procedure/2574520557>,
#  <SyncFHIRResource Procedure/2574520547>,
#  <SyncFHIRResource Procedure/2574520537>,
#  <SyncFHIRResource Procedure/2574520527>,
#  <SyncFHIRResource Procedure/2574520521>,
#  <SyncFHIRResource Procedure/2574520515>,
#  <SyncFHIRResource Procedure/2574520509>,
#  <SyncFHIRResource Procedure/2574520503>,
#  <SyncFHIRResource Procedure/2574520497>,
#  <SyncFHIRResource Procedure/2574520491>,
#  <SyncFHIRResource Procedure/2574520485>,
#  <SyncFHIRResource Procedure/2574520467>,
#  <SyncFHIRResource Procedure/2574520461>,
#  <SyncFHIRResource Procedure/2574520455>,
#  <SyncFHIRResource Procedure/2574520449>,
#  <SyncFHIRResource Procedure/2574520443>,
#  <SyncFHIRResource Procedure/2574637373>,
#  <SyncFHIRResource Procedure/2574522881>,
#  <SyncFHIRResource Procedure/2574522853>,
#  <SyncFHIRResource Procedure/2574522843>,
#  <SyncFHIRResource Procedure/2574520437>,
#  <SyncFHIRResource Procedure/2574520431>,
#  <SyncFHIRResource Procedure/2574520421>]

# %%
procedure = client.resource("Procedure")
procedure.id = 2574524413
procedure.refresh()

# %%
pp(procedure['encounter'])
# Out:
# {
#   "reference": "Encounter/97953477"
# }

# %%
procedure["location"]["reference"]
# Out:
# 'Location/21250409'

# %%
location = client.resource("Location")
location.id = 21250409
location.refresh()

# %%
pp(location)
# Out:
# {
#   "resourceType": "Location",
#   "id": "21250409",
#   "meta": {
#     "versionId": "29",
#     "lastUpdated": "2020-11-18T15:56:00Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Location</b></p><p><b>Name</b>: Model Hospital</p><p><b>Alias</b>: MX Hospital</p><p><b>Managing Organization</b>: Model Hospital</p><p><b>Part Of</b>: 21250403</p><p><b>Physical Type</b>: Building(s)</p><p><b>Status</b>: Active</p></div>"
#   },
#   "status": "active",
#   "name": "Model Hospital",
#   "alias": [
#     "MX Hospital"
#   ],
#   "mode": "instance",
#   "telecom": [
#     {
#       "system": "fax",
#       "value": "3239898888"
#     }
#   ],
#   "physicalType": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/222",
#         "code": "778",
#         "display": "Building(s)",
#         "userSelected": true
#       },
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#         "code": "bu",
#         "display": "Building"
#       }
#     ],
#     "text": "Building(s)"
#   },
#   "managingOrganization": {
#     "reference": "Organization/675844",
#     "display": "Model Hospital"
#   },
#   "partOf": {
#     "reference": "Location/21250403"
#   }
# }

# %%
rooms = client.resources("Location").search(Raw(**{'-physicalType': 'ro'})).fetch()

# %%
pp(rooms[0])
# Out:
# {
#   "resourceType": "Location",
#   "id": "28216217",
#   "meta": {
#     "versionId": "3",
#     "lastUpdated": "2016-09-27T19:21:07Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Location</b></p><p><b>Name</b>: 01</p><p><b>Alias</b>: 01</p><p><b>Managing Organization</b>: zzLG_Logan Regional Hospital</p><p><b>Part Of</b>: 28170721</p><p><b>Physical Type</b>: Room(s)</p><p><b>Status</b>: Active</p></div>"
#   },
#   "extension": [
#     {
#       "extension": [
#         {
#           "id": "2553253085",
#           "valueString": "ED/Hold Link",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueCodeableConcept": {
#             "coding": [
#               {
#                 "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/4678015",
#                 "code": "109167639",
#                 "display": "V01",
#                 "userSelected": true
#               }
#             ],
#             "text": "V01"
#           },
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     }
#   ],
#   "status": "active",
#   "name": "01",
#   "alias": [
#     "01"
#   ],
#   "mode": "instance",
#   "physicalType": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/222",
#         "code": "801",
#         "display": "Room(s)",
#         "userSelected": true
#       },
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#         "code": "ro",
#         "display": "Room"
#       }
#     ],
#     "text": "Room(s)"
#   },
#   "managingOrganization": {
#     "reference": "Organization/900423",
#     "display": "zzLG_Logan Regional Hospital"
#   },
#   "partOf": {
#     "reference": "Location/28170721"
#   }
# }

# %%
apointments = client.resources("Appointment").search(patient='12724066',date__ge='2023-01-01T09:00:00Z').fetch()
apointments
# Out:
# [<SyncFHIRResource Appointment/4857758>,
#  <SyncFHIRResource Appointment/4840584>,
#  <SyncFHIRResource Appointment/4840585>,
#  <SyncFHIRResource Appointment/4840586>,
#  <SyncFHIRResource Appointment/4840587>,
#  <SyncFHIRResource Appointment/4840588>,
#  <SyncFHIRResource Appointment/4840589>,
#  <SyncFHIRResource Appointment/4840590>,
#  <SyncFHIRResource Appointment/4840591>,
#  <SyncFHIRResource Appointment/4840592>]

# %%
[a['status'] for a in apointments]
# Out:
# ['cancelled',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow',
#  'noshow']

# %%
appointment = client.resource("Appointment", id="4857758")
appointment.refresh()

# %%
pp(appointment)
# Out:
# {
#   "resourceType": "Appointment",
#   "id": "4857758",
#   "meta": {
#     "versionId": "1",
#     "lastUpdated": "2022-12-01T03:49:38Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Appointment</b></p><p><b>Status</b>: Cancelled</p><p><b>Service Type</b>: New Patient</p><p><b>Participants</b>:</p><dl><dd><b>Location</b>: MX Clinic 1</dd><dd><b>Practitioner</b>: Porter, Andy Cerner</dd><dd><b>Practitioner</b>: PWAffirm Health, MD, Cardio</dd><dd><b>Practitioner</b>: PWDRDOCTOR, MD, CARDIO</dd><dd><b>Practitioner</b>: PWGeminiHealth, MD, Cardio</dd><dd><b>Practitioner</b>: Applegate MD, Christina</dd><dd><b>Practitioner</b>: Nuance, DAX</dd><dd><b>Patient</b>: SMART III, NANCYU NHA EEEEEE</dd></dl></div>"
#   },
#   "extension": [
#     {
#       "valueBoolean": false,
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/is-cancelable"
#     },
#     {
#       "valueBoolean": false,
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/is-reschedulable"
#     }
#   ],
#   "status": "cancelled",
#   "cancelationReason": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14229",
#         "code": "26491409",
#         "display": "Patient Other",
#         "userSelected": true
#       },
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/appointment-cancellation-reason",
#         "code": "pat",
#         "display": "Patient",
#         "userSelected": false
#       }
#     ],
#     "text": "Patient Other"
#   },
#   "serviceType": [
#     {
#       "coding": [
#         {
#           "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14249",
#           "code": "24477838",
#           "display": "New Patient",
#           "userSelected": true
#         },
#         {
#           "system": "http://snomed.info/sct",
#           "code": "408443003",
#           "display": "General medical practice (qualifier value)",
#           "userSelected": false
#         }
#       ],
#       "text": "New Patient"
#     }
#   ],
#   "reasonCode": [
#     {
#       "text": "I have a cramp"
#     }
#   ],
#   "description": "New Patient",
#   "comment": "Appointment request comment",
#   "participant": [
#     {
#       "actor": {
#         "reference": "Location/21304876",
#         "display": "MX Clinic 1"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/4122620",
#         "display": "Porter, Andy Cerner"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/12793349",
#         "display": "PWAffirm Health, MD, Cardio"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/12763452",
#         "display": "PWDRDOCTOR, MD, CARDIO"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/12753114",
#         "display": "PWGeminiHealth, MD, Cardio"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/593923",
#         "display": "Applegate MD, Christina"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "0",
#               "userSelected": true
#             }
#           ]
#         },
#         {
#           "coding": [
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer"
#             }
#           ]
#         }
#       ],
#       "actor": {
#         "reference": "Practitioner/12821212",
#         "display": "Nuance, DAX"
#       },
#       "required": "required",
#       "status": "accepted"
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14250",
#               "code": "4572",
#               "display": "Patient",
#               "userSelected": true
#             }
#           ],
#           "text": "Patient"
#         }
#       ],
#       "actor": {
#         "reference": "Patient/12724066",
#         "display": "SMART III, NANCYU NHA EEEEEE"
#       },
#       "required": "required",
#       "status": "accepted"
#     }
#   ],
#   "requestedPeriod": [
#     {
#       "start": "2022-02-07T18:28:17Z",
#       "end": "2023-02-07T18:28:17Z"
#     }
#   ]
# }

# %%
encounter = client.resource("Encounter", id=97953477)
encounter.refresh()

# %%
pp(encounter)
# Out:
# {
#   "resourceType": "Encounter",
#   "id": "97953477",
#   "meta": {
#     "versionId": "2",
#     "lastUpdated": "2020-03-05T16:53:11.000Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Encounter</b></p><p><b>Patient</b>: SMART III, NANCYU NHA EEEEEE</p><p><b>Location</b>: Model Hospital, MX Hospital, MAT, MB01, A</p><p><b>Type</b>: Inpatient</p><p><b>Service Type</b>: Maternity</p><p><b>Class</b>: inpatient encounter</p><p><b>Status</b>: In Progress</p><p><b>Period Start Date</b>: Mar  4, 2020  5:01 P.M. UTC</p><p><b>Reason For Visit</b>: Maternity</p><p><b>Attending Physician</b>: Carter, Kristin Cerner</p><p><b>Service Provider</b>: Model Hospital</p></div>"
#   },
#   "extension": [
#     {
#       "id": "CA-0",
#       "extension": [
#         {
#           "id": "ENCNTR:204298207",
#           "valueString": "Full Reg User ID",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueString": "JG015148",
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     },
#     {
#       "id": "CA-1",
#       "extension": [
#         {
#           "id": "ENCNTR:17368048",
#           "valueString": "Full Reg Date/Time",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueDateTime": "2020-03-04T17:19:39.000Z",
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     },
#     {
#       "id": "CA-2",
#       "extension": [
#         {
#           "id": "ENCNTR:4047481",
#           "valueString": "Conversation",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueCodeableConcept": {
#             "coding": [
#               {
#                 "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/100040",
#                 "code": "4630114",
#                 "display": "Register Patient",
#                 "userSelected": true
#               }
#             ],
#             "text": "Register Patient"
#           },
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     },
#     {
#       "id": "CA-3",
#       "extension": [
#         {
#           "id": "ENCNTR:34310433",
#           "valueString": "Complete Reg?",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueCodeableConcept": {
#             "coding": [
#               {
#                 "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/20322",
#                 "code": "3542949",
#                 "display": "Yes",
#                 "userSelected": true
#               }
#             ],
#             "text": "Yes"
#           },
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     },
#     {
#       "id": "CA-4",
#       "extension": [
#         {
#           "id": "ENCNTR:684109",
#           "valueString": "Accident Related Visit",
#           "url": "custom-attribute-name"
#         },
#         {
#           "valueCodeableConcept": {
#             "coding": [
#               {
#                 "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/100700",
#                 "code": "684155",
#                 "display": "No",
#                 "userSelected": true
#               }
#             ],
#             "text": "No"
#           },
#           "url": "custom-attribute-value"
#         }
#       ],
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/custom-attribute"
#     },
#     {
#       "valueMoney": {
#         "value": 0.0,
#         "currency": "USD"
#       },
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/estimated-financial-responsibility-amount"
#     }
#   ],
#   "identifier": [
#     {
#       "use": "usual",
#       "type": {
#         "coding": [
#           {
#             "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/319",
#             "code": "1077",
#             "display": "FIN NBR",
#             "userSelected": true
#           },
#           {
#             "system": "http://terminology.hl7.org/CodeSystem/v2-0203",
#             "code": "AN",
#             "display": "Account number",
#             "userSelected": false
#           }
#         ],
#         "text": "FIN NBR"
#       },
#       "system": "urn:oid:5.5.5.5.5.5.",
#       "value": "16000",
#       "period": {
#         "start": "2020-03-04T17:19:56.000Z"
#       }
#     }
#   ],
#   "status": "in-progress",
#   "class": {
#     "system": "http://terminology.hl7.org/CodeSystem/v3-ActCode",
#     "code": "IMP",
#     "display": "inpatient encounter",
#     "userSelected": false
#   },
#   "type": [
#     {
#       "coding": [
#         {
#           "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/71",
#           "code": "309308",
#           "display": "Inpatient",
#           "userSelected": true
#         },
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/v2-0004",
#           "code": "I",
#           "display": "Inpatient",
#           "userSelected": false
#         }
#       ],
#       "text": "Inpatient"
#     }
#   ],
#   "serviceType": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/34",
#         "code": "29308009",
#         "display": "Maternity",
#         "userSelected": true
#       },
#       {
#         "system": "http://snomed.info/sct",
#         "code": "310063007",
#         "display": "Obstetrics service (qualifier value)",
#         "userSelected": false
#       }
#     ],
#     "text": "Maternity"
#   },
#   "priority": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/3",
#         "code": "309204",
#         "display": "Labor and Delivery",
#         "userSelected": true
#       },
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/v3-ActPriority",
#         "code": "UR",
#         "display": "urgent",
#         "userSelected": false
#       }
#     ],
#     "text": "Labor and Delivery"
#   },
#   "subject": {
#     "reference": "Patient/12724066",
#     "display": "SMART III, NANCYU NHA EEEEEE"
#   },
#   "participant": [
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1116",
#               "display": "Admitting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "ADM",
#               "display": "admitter",
#               "userSelected": false
#             }
#           ],
#           "text": "Admitting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-03-05T16:53:11.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/4122622",
#         "display": "Cerner Test, Physician - Hospitalist Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1119",
#               "display": "Attending Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "ATND",
#               "display": "attender",
#               "userSelected": false
#             }
#           ],
#           "text": "Attending Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-03-04T17:19:56.000Z",
#         "end": "2020-03-05T16:53:11.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/4122630",
#         "display": "Cerner Test, Physician - Women's Health Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1119",
#               "display": "Attending Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "ATND",
#               "display": "attender",
#               "userSelected": false
#             }
#           ],
#           "text": "Attending Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-03-05T16:53:11.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/11817978",
#         "display": "Carter, Kristin Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1120",
#               "display": "Case Manager",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Case Manager"
#         }
#       ],
#       "period": {
#         "start": "2021-04-20T16:27:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/744079",
#         "display": "Cerner Test, Case Manager Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2022-11-23T14:42:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12743338",
#         "display": "PWXealth, MDCardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2022-08-05T14:15:50.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742069",
#         "display": "Portal, Portal"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2022-02-21T19:01:15.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/639925",
#         "display": "Cerner Test, Clinical Research - Investigator Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2021-10-27T21:48:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12761549",
#         "display": "PWVeeOne, MD, Cardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2021-09-14T00:41:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12753114",
#         "display": "PWGeminiHealth, MD, Cardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2021-09-07T20:33:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12732049",
#         "display": "PWUpToDate, Physician - Primary Care"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2021-07-30T19:07:55.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12744716",
#         "display": "PWIntouch, MDCardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-11-24T04:55:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12744428",
#         "display": "PWCarePlaces, MD Cardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-11-19T19:35:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742614",
#         "display": "PWSUKI, MDCARDIO"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-07-24T18:26:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724064",
#         "display": "Spence, Open Platform IA, Stephen"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-06-16T21:10:02.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12732076",
#         "display": "PWIMO, Physician - Hospitalist"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1121",
#               "display": "Consulting Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "CON",
#               "display": "consultant",
#               "userSelected": false
#             }
#           ],
#           "text": "Consulting Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-06-16T21:08:27.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/763923",
#         "display": "Cerner Test, Physician - Oncology Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2021-01-15T02:02:26.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742070",
#         "display": "Kheang, Kol"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-11-18T11:22:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/1",
#         "display": "SYSTEM, SYSTEM Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-11-09T20:00:42.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12743472",
#         "display": "Allen, Jodi"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-10-27T22:16:10.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742563",
#         "display": "Pivonka, Fran"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-10-21T17:33:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742566",
#         "display": "McGinn, Aaron"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-10-08T18:50:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12744840",
#         "display": "Lara, Tomas"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-09-08T22:25:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12743116",
#         "display": "Ali, Seada"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-08-11T13:55:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12736052",
#         "display": "Scott, Justin"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1124",
#               "display": "Other",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Other"
#         }
#       ],
#       "period": {
#         "start": "2020-04-21T16:19:37.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742510",
#         "display": "Kaehr, Andrew"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1125",
#               "display": "Registered Nurse",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Registered Nurse"
#         }
#       ],
#       "period": {
#         "start": "2021-11-03T20:19:06.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742613",
#         "display": "PWSuki, RN"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1125",
#               "display": "Registered Nurse",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Registered Nurse"
#         }
#       ],
#       "period": {
#         "start": "2020-09-02T19:24:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742577",
#         "display": "MedActionPlanRN, PW"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1125",
#               "display": "Registered Nurse",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Registered Nurse"
#         }
#       ],
#       "period": {
#         "start": "2020-09-01T19:58:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742577",
#         "display": "MedActionPlanRN, PW"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1125",
#               "display": "Registered Nurse",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Registered Nurse"
#         }
#       ],
#       "period": {
#         "start": "2020-03-05T16:53:00.000Z",
#         "end": "2020-03-06T09:01:27.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/683925",
#         "display": "Cerner Test, Women's Health - Nurse Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "1126",
#               "display": "Referring Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "REF",
#               "display": "referrer",
#               "userSelected": false
#             }
#           ],
#           "text": "Referring Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-03-04T17:19:56.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/4122630",
#         "display": "Cerner Test, Physician - Women's Health Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "2796735",
#               "display": "Pharmacist",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Pharmacist"
#         }
#       ],
#       "period": {
#         "start": "2022-11-01T04:41:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12732058",
#         "display": "PWDoseMeRX, PharmNet - Pharmacist"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2022-04-22T17:19:07.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681295",
#               "display": "Physician (Office/Clinic Only)",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Physician (Office/Clinic Only)"
#         }
#       ],
#       "period": {
#         "start": "2022-03-19T02:07:06.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12753672",
#         "display": "PWZoom, MD Cardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681290",
#               "display": "Ambulatory: Medical Assistant",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "SPRF",
#               "display": "secondary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Ambulatory: Medical Assistant"
#         }
#       ],
#       "period": {
#         "start": "2022-02-24T18:29:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/4112224",
#         "display": "Cerner Test, Ambulatory - MA Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681295",
#               "display": "Physician (Office/Clinic Only)",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Physician (Office/Clinic Only)"
#         }
#       ],
#       "period": {
#         "start": "2022-01-21T14:11:38.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12773429",
#         "display": "PWEPION2, MDCardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681295",
#               "display": "Physician (Office/Clinic Only)",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Physician (Office/Clinic Only)"
#         }
#       ],
#       "period": {
#         "start": "2021-09-14T19:20:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12762972",
#         "display": "PWEPION, MDCardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-09-02T15:04:24.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-08-31T17:14:56.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12752837",
#         "display": "Babcock, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-08-25T14:25:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-08-24T19:59:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-08-23T13:40:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "18883355",
#               "display": "Covering Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Covering Physician"
#         }
#       ],
#       "period": {
#         "start": "2021-07-30T20:21:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12750336",
#         "display": "PWMicrosoft, MD, Cardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-07-21T20:42:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12718044",
#         "display": "Mckenzie, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-07-13T15:49:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-07-12T20:16:24.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12718044",
#         "display": "Mckenzie, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-07-09T18:36:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-19T12:17:35.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12747957",
#         "display": "Patterson, Dennis"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-18T14:32:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12747957",
#         "display": "Patterson, Dennis"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-17T19:38:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12747957",
#         "display": "Patterson, Dennis"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-14T17:05:19.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742564",
#         "display": "Rattazzi, Joe"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-07T19:00:48.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-06T13:36:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-05-05T16:12:20.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
# ...
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2021-01-05T14:52:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-12-29T15:00:24.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-12-03T16:02:10.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-11-30T20:40:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12740131",
#         "display": "Desani, Fenil"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "242348525",
#               "display": "Chart Review",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Chart Review"
#         }
#       ],
#       "period": {
#         "start": "2020-11-24T18:33:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12746397",
#         "display": "Pwuptodate, RN"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-11-19T14:17:05.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-11-18T19:27:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-10-22T13:45:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-10-20T20:42:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742072",
#         "display": "Hanson, Nick"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "242348525",
#               "display": "Chart Review",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Chart Review"
#         }
#       ],
#       "period": {
#         "start": "2020-10-14T18:44:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/607928",
#         "display": "Cerner Test, Nurse Cerner"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-10-14T16:34:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742563",
#         "display": "Pivonka, Fran"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-10-02T13:48:00.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-08-03T15:50:00.000Z",
#         "end": "2020-08-04T04:01:14.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12740131",
#         "display": "Desani, Fenil"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-07-16T13:55:00.000Z",
#         "end": "2020-07-17T02:01:01.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724064",
#         "display": "Spence, Open Platform IA, Stephen"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-07-07T15:04:16.000Z",
#         "end": "2020-07-08T04:01:47.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724064",
#         "display": "Spence, Open Platform IA, Stephen"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-07-06T19:25:00.000Z",
#         "end": "2020-07-07T08:01:33.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724064",
#         "display": "Spence, Open Platform IA, Stephen"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "18883355",
#               "display": "Covering Physician",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PPRF",
#               "display": "primary performer",
#               "userSelected": false
#             }
#           ],
#           "text": "Covering Physician"
#         }
#       ],
#       "period": {
#         "start": "2020-07-06T13:06:19.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12742668",
#         "display": "PwHealthEndeavors, MDCardio"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-06-22T21:32:00.000Z",
#         "end": "2020-06-23T10:01:31.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12736052",
#         "display": "Scott, Justin"
#       }
#     },
#     {
#       "type": [
#         {
#           "coding": [
#             {
#               "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/333",
#               "code": "681274",
#               "display": "Database Coordinator",
#               "userSelected": true
#             },
#             {
#               "system": "http://terminology.hl7.org/CodeSystem/v3-ParticipationType",
#               "code": "PART",
#               "display": "Participation",
#               "userSelected": false
#             }
#           ],
#           "text": "Database Coordinator"
#         }
#       ],
#       "period": {
#         "start": "2020-03-13T16:20:00.000Z",
#         "end": "2020-03-14T05:01:18.000Z"
#       },
#       "individual": {
#         "reference": "Practitioner/12724045",
#         "display": "Graham, Joshua"
#       }
#     }
#   ],
#   "period": {
#     "start": "2020-03-04T17:01:59.000Z"
#   },
#   "reasonCode": [
#     {
#       "text": "Maternity"
#     }
#   ],
#   "hospitalization": {
#     "admitSource": {
#       "coding": [
#         {
#           "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/2",
#           "code": "309200",
#           "display": "Information Not Available",
#           "userSelected": true
#         },
#         {
#           "system": "http://terminology.hl7.org/CodeSystem/admit-source",
#           "code": "other",
#           "display": "Other",
#           "userSelected": false
#         }
#       ],
#       "text": "Information Not Available"
#     }
#   },
#   "location": [
#     {
#       "location": {
#         "reference": "Location/31100793",
#         "display": "Model Hospital, MX Hospital, MAT, MB01, A"
#       },
#       "status": "active"
#     }
#   ],
#   "serviceProvider": {
#     "reference": "Organization/675844",
#     "display": "Model Hospital"
#   }
# }

# %%
slots = client.resources("Slot").search(
    service_type="https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14249|4047611",
    start__ge='2023-03-15T09:00:00Z',
    start__lt='2023-03-16T09:00:00Z',
).fetch()

# %%
pp(slots[0])
# Out:
# {
#   "resourceType": "Slot",
#   "id": "4047611-32216049-64412869-240",
#   "meta": {
#     "versionId": "34245157v580283",
#     "lastUpdated": "2022-02-13T08:10:35Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Slot</b></p><p><b>Service Type</b>: Surgery Rapid</p><p><b>Start</b>: Mar 15, 2023  9:00 A.M. UTC</p><p><b>End</b>: Mar 15, 2023 10:00 A.M. UTC</p><p><b>Schedule Reference</b>: 4047611-32216049-64412869-240</p><p><b>Status</b>: Free</p></div>"
#   },
#   "extension": [
#     {
#       "valueReference": {
#         "reference": "Location/32216049"
#       },
#       "url": "https://fhir-ehr.cerner.com/r4/StructureDefinition/scheduling-location"
#     }
#   ],
#   "serviceType": [
#     {
#       "coding": [
#         {
#           "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14249",
#           "code": "4047611",
#           "display": "Surgery Rapid",
#           "userSelected": true
#         },
#         {
#           "system": "http://snomed.info/sct",
#           "code": "394576009",
#           "display": "Accident & emergency (qualifier value)"
#         }
#       ],
#       "text": "Surgery Rapid"
#     }
#   ],
#   "schedule": {
#     "reference": "Schedule/4047611-32216049-64412869-240"
#   },
#   "status": "free",
#   "start": "2023-03-15T09:00:00Z",
#   "end": "2023-03-15T10:00:00Z"
# }

# %%
schedule = client.resources("Schedule").search(_id="4047611-32216049-64412869-240").get()
pp(schedule)
# Out:
# {
#   "resourceType": "Schedule",
#   "id": "4047611-32216049-64412869-240",
#   "meta": {
#     "versionId": "34245157v580283",
#     "lastUpdated": "2022-02-13T08:10:35Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Schedule</b></p><p><b>Status</b>: Active</p><p><b>Service Type</b>: Surgery Rapid</p><p><b>Location</b>: Endoscopy</p></div>"
#   },
#   "active": true,
#   "serviceType": [
#     {
#       "coding": [
#         {
#           "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/14249",
#           "code": "4047611",
#           "display": "Surgery Rapid",
#           "userSelected": true
#         },
#         {
#           "system": "http://snomed.info/sct",
#           "code": "394576009",
#           "display": "Accident & emergency (qualifier value)"
#         }
#       ],
#       "text": "Surgery Rapid"
#     }
#   ],
#   "actor": [
#     {
#       "reference": "Location/32216049",
#       "display": "Endoscopy"
#     }
#   ]
# }

# %%
l=client.resources("Location").search(_id="32216049").get()
pp(l)
# Out:
# {
#   "resourceType": "Location",
#   "id": "32216049",
#   "meta": {
#     "versionId": "7",
#     "lastUpdated": "2016-08-29T17:08:01Z"
#   },
#   "text": {
#     "status": "generated",
#     "div": "<div xmlns=\"http://www.w3.org/1999/xhtml\"><p><b>Location</b></p><p><b>Name</b>: Endoscopy</p><p><b>Alias</b>: Endoscopy</p><p><b>Managing Organization</b>: Model Hospital</p><p><b>Part Of</b>: 21250409</p><p><b>Physical Type</b>: Surgery</p><p><b>Status</b>: Active</p></div>"
#   },
#   "status": "active",
#   "name": "Endoscopy",
#   "alias": [
#     "Endoscopy"
#   ],
#   "mode": "instance",
#   "physicalType": {
#     "coding": [
#       {
#         "system": "https://fhir.cerner.com/ec2458f2-1e24-41c8-b71b-0e701af7583d/codeSet/222",
#         "code": "817",
#         "display": "Surgery",
#         "userSelected": true
#       },
#       {
#         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#         "code": "wa",
#         "display": "Ward"
#       }
#     ],
#     "text": "Surgery"
#   },
#   "managingOrganization": {
#     "reference": "Organization/675844",
#     "display": "Model Hospital"
#   },
#   "partOf": {
#     "reference": "Location/21250409"
#   }
# }

# %%
apointments = client.resources("Appointment").search(location='32216049',date__ge='2023-01-01T09:00:00Z').fetch()
apointments
# Out:
# [<SyncFHIRResource Appointment/4838660>,
#  <SyncFHIRResource Appointment/4862666>,
#  <SyncFHIRResource Appointment/4855119>,
#  <SyncFHIRResource Appointment/4875638>,
#  <SyncFHIRResource Appointment/4875730>,
#  <SyncFHIRResource Appointment/4875728>,
#  <SyncFHIRResource Appointment/4875729>,
#  <SyncFHIRResource Appointment/4870766>,
#  <SyncFHIRResource Appointment/4872582>,
#  <SyncFHIRResource Appointment/4873057>]

# %%
patients = set(p.split("/")[1] for p in fhirpath(apointments, "Appointment.participant.where(type.coding.code = '4572').actor.reference"))
patients
# Out:
# {'12724066', '12754465', '12755128', '12802992'}

# %%
encounters = [client.resources("Encounter").search(patient=p).fetch() for p in patients]

# %%
encounters = [e for e in funcy.flatten(encounters)]

# %%
locations = client.resources("Location").search(Raw(**{'-physicalType': 'wa'})).fetch()

# %%
fhirpath(locations, """
Location.where(physicalType.coding.code contains '817').name""")
# Out:
# ['ASC OR',
#  'Anesthesia Out of Department',
#  'Cath Lab',
#  'Echo',
#  'Endoscopy',
#  'Labor and Delivery OR',
#  'Main OR',
#  'PreAdmission Testing']
